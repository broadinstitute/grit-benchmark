# %% [markdown]
# # Calculate grit for different Cell Profiler feature groups
#
# * Per compartment (Cells, Cytoplasm, Nuclei)
# * Per compartment feature group (Cells x AreaShape, Cells x Correlation, Nuclei x Texture, etc.)
# * Per channel (DNA, RNA, AGP, ER, Mito)
#     * Use all features that include any information from one of these channels

# %%
import pathlib
import numpy as np
import pandas as pd

from pycytominer.cyto_utils import infer_cp_features

from cytominer_eval import evaluate

# %%
compartments = ["Cells", "Cytoplasm", "Nuclei"]

# %%
# Load Cell Health data
data_file = pathlib.Path("data/cell_health_merged_feature_select.csv.gz")

df = pd.read_csv(data_file, sep=",")

print(df.shape)
df.head(2)
# Out:
# (3456, 402)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014618           A01                 1                A
# 1     SQ00014618           A02                 2                A
#
#   Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0              HCC44              EMPTY              EMPTY
# 1              HCC44               MCL1             MCL1-5
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0                    -1.515696                0.810956
# 1                     0.246423                0.687241
#
#    Cells_AreaShape_Zernike_0_0  ...  \
# 0                     1.984031  ...
# 1                     0.062305  ...
#
#    Nuclei_Texture_InverseDifferenceMoment_Mito_5_0  \
# 0                                        -1.365392
# 1                                        -0.070069
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_10_0  \
# 0                                        -0.351107
# 1                                         1.855687
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_20_0  \
# 0                                        -0.163153
# 1                                        -0.400335
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumAverage_ER_5_0  \
# 0                           2.307568                         -2.775524
# 1                           3.776635                          0.947498
#
#    Nuclei_Texture_SumAverage_Mito_20_0  Nuclei_Texture_SumAverage_RNA_5_0  \
# 0                            -3.951667                          -1.716353
# 1                            -0.541032                           0.363568
#
#    Nuclei_Texture_SumEntropy_ER_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                         -2.703082                           -3.720976
# 1                          0.910251                           -0.364015
#
#    Nuclei_Texture_SumEntropy_RNA_5_0
# 0                           0.107581
# 1                           0.165935
#
# [2 rows x 402 columns]

# %%
# Define cell health constants
barcode_col = "Metadata_pert_name"
gene_col = "Metadata_gene_name"

replicate_group_grit = {
    "profile_col": barcode_col,
    "replicate_group_col": gene_col
}

control_group_cut = ["Chr2", "Luc", "LacZ"]

control_barcodes = (
    df.loc[
        df[replicate_group_grit["replicate_group_col"]].isin(control_group_cut),
        replicate_group_grit["profile_col"]
    ]
    .unique()
    .tolist()
)

control_barcodes
# Out:
# ['Chr2-1',
#  'Chr2-4',
#  'Chr2-5',
#  'Chr2-2',
#  'Luc-1',
#  'LacZ-3',
#  'Luc-2',
#  'LacZ-2',
#  'Chr2-3',
#  'Chr2-6']

# %%
all_features = infer_cp_features(df, compartments=compartments)
meta_features = infer_cp_features(df, metadata=True)

meta_features
# Out:
# ['Metadata_Plate',
#  'Metadata_Well',
#  'Metadata_WellCol',
#  'Metadata_WellRow',
#  'Metadata_cell_line',
#  'Metadata_gene_name',
#  'Metadata_pert_name']

# %%
grit_compartment_results = []
for cell_line in df.Metadata_cell_line.unique():
    for compartment in compartments:
        compartment_features = infer_cp_features(df, compartments=compartment)
        
        for drop in [True, False]:
            
            if drop:
                subset_df = df.drop(compartment_features, axis="columns")
                dropped_or_exclusive = "dropped"
                use_features = subset_df.drop(meta_features, axis="columns").columns.tolist()
            else:
                subset_df = df.loc[:, meta_features + compartment_features]
                dropped_or_exclusive = "exclusive"
                use_features = compartment_features

            result = evaluate(
                profiles=subset_df.query("Metadata_cell_line == @cell_line"),
                features=use_features,
                meta_features=[barcode_col, gene_col],
                replicate_groups=replicate_group_grit,
                operation="grit",
                similarity_metric="pearson",
                grit_control_perts=control_barcodes
            ).assign(
                cell_line=cell_line,
                barcode_control="cutting_control",
                cor_method="pearson",
                compartment=compartment,
                channel="all",
                feature_group="all",
                num_features=len(compartment_features),
                dropped_or_exclusive=dropped_or_exclusive
            )

            grit_compartment_results.append(result)
        
grit_compartment_results = pd.concat(grit_compartment_results).reset_index(drop=True)

print(grit_compartment_results.shape)
grit_compartment_results.head()
# Out:
# (2142, 11)
#   perturbation   group      grit cell_line  barcode_control cor_method  \
# 0       AKT1-1    AKT1  0.821396     HCC44  cutting_control    pearson
# 1       AKT1-2    AKT1  0.799205     HCC44  cutting_control    pearson
# 2     ARID1B-1  ARID1B  0.425039     HCC44  cutting_control    pearson
# 3     ARID1B-2  ARID1B  0.310649     HCC44  cutting_control    pearson
# 4       ATF4-1    ATF4  0.231863     HCC44  cutting_control    pearson
#
#   compartment channel feature_group  num_features dropped_or_exclusive
# 0       Cells     all           all           100              dropped
# 1       Cells     all           all           100              dropped
# 2       Cells     all           all           100              dropped
# 3       Cells     all           all           100              dropped
# 4       Cells     all           all           100              dropped

# %% [markdown]
# ## Calculate grit for feature groups

# %%
feature_group_compartments = list(set(["_".join(x.split("_")[0:2]) for x in all_features]))

grit_subcompartment_results = []
for cell_line in df.Metadata_cell_line.unique():
    for compartment_group in feature_group_compartments:
        compartment, feature_group = compartment_group.split("_")
        compartment_features = df.loc[:, df.columns.str.startswith(compartment_group)].columns.tolist()
            
        for drop in [True, False]:
            
            if drop:
                subset_df = df.drop(compartment_features, axis="columns")
                dropped_or_exclusive = "dropped"
                use_features = subset_df.drop(meta_features, axis="columns").columns.tolist()
            else:
                subset_df = df.loc[:, meta_features + compartment_features]
                dropped_or_exclusive = "exclusive"
                use_features = compartment_features

            result = evaluate(
                profiles=subset_df.query("Metadata_cell_line == @cell_line"),
                features=use_features,
                meta_features=[barcode_col, gene_col],
                replicate_groups=replicate_group_grit,
                operation="grit",
                similarity_metric="pearson",
                grit_control_perts=control_barcodes
            ).assign(
                cell_line=cell_line,
                barcode_control="cutting_control",
                cor_method="pearson",
                compartment=compartment,
                channel="all",
                feature_group=feature_group,
                num_features=len(compartment_features),
                dropped_or_exclusive=dropped_or_exclusive
            )

            grit_subcompartment_results.append(result)
        
grit_subcompartment_results = pd.concat(grit_subcompartment_results).reset_index(drop=True)

print(grit_subcompartment_results.shape)
grit_subcompartment_results.head()
# Out:
# (13566, 11)
#   perturbation   group      grit cell_line  barcode_control cor_method  \
# 0       AKT1-1    AKT1  0.807500     HCC44  cutting_control    pearson
# 1       AKT1-2    AKT1  0.801166     HCC44  cutting_control    pearson
# 2     ARID1B-1  ARID1B  0.438915     HCC44  cutting_control    pearson
# 3     ARID1B-2  ARID1B  0.325934     HCC44  cutting_control    pearson
# 4       ATF4-1    ATF4  0.258981     HCC44  cutting_control    pearson
#
#   compartment channel feature_group  num_features dropped_or_exclusive
# 0       Cells     all       Texture            23              dropped
# 1       Cells     all       Texture            23              dropped
# 2       Cells     all       Texture            23              dropped
# 3       Cells     all       Texture            23              dropped
# 4       Cells     all       Texture            23              dropped

# %% [markdown]
# ## Calculate grit for channels

# %%
channels = ["DNA", "RNA", "Mito", "AGP", "ER"]

grit_channel_results = []
for cell_line in df.Metadata_cell_line.unique():
    for channel in channels:
        channel_features = df.loc[:, df.columns.str.contains(channel)].columns.tolist()
        
        for drop in [True, False]:
            
            if drop:
                subset_df = df.drop(channel_features, axis="columns")
                dropped_or_exclusive = "dropped"
                use_features = subset_df.drop(meta_features, axis="columns").columns.tolist()
            else:
                subset_df = df.loc[:, meta_features + channel_features]
                dropped_or_exclusive = "exclusive"
                use_features = channel_features

            result = evaluate(
                profiles=subset_df.query("Metadata_cell_line == @cell_line"),
                features=use_features,
                meta_features=[barcode_col, gene_col],
                replicate_groups=replicate_group_grit,
                operation="grit",
                similarity_metric="pearson",
                grit_control_perts=control_barcodes
            ).assign(
                cell_line=cell_line,
                barcode_control="cutting_control",
                cor_method="pearson",
                compartment="all",
                channel=channel,
                feature_group="all",
                num_features=len(channel_features),
                dropped_or_exclusive=dropped_or_exclusive
            )

            grit_channel_results.append(result)
        
grit_channel_results = pd.concat(grit_channel_results).reset_index(drop=True)

print(grit_channel_results.shape)
grit_channel_results.head()
# Out:
# (3570, 11)
#   perturbation   group      grit cell_line  barcode_control cor_method  \
# 0       AKT1-1    AKT1  0.835799     HCC44  cutting_control    pearson
# 1       AKT1-2    AKT1  0.836772     HCC44  cutting_control    pearson
# 2     ARID1B-1  ARID1B  0.491000     HCC44  cutting_control    pearson
# 3     ARID1B-2  ARID1B  0.395005     HCC44  cutting_control    pearson
# 4       ATF4-1    ATF4  0.263493     HCC44  cutting_control    pearson
#
#   compartment channel feature_group  num_features dropped_or_exclusive
# 0         all     DNA           all            78              dropped
# 1         all     DNA           all            78              dropped
# 2         all     DNA           all            78              dropped
# 3         all     DNA           all            78              dropped
# 4         all     DNA           all            78              dropped

# %% [markdown]
# ## Concatenate results together

# %%
full_grit_results = pd.concat(
    [
        grit_compartment_results,
        grit_subcompartment_results,
        grit_channel_results,
    ],
    axis="rows"
).reset_index(drop=True)

print(full_grit_results.shape)
full_grit_results.head()
# Out:
# (19278, 11)
#   perturbation   group      grit cell_line  barcode_control cor_method  \
# 0       AKT1-1    AKT1  0.821396     HCC44  cutting_control    pearson
# 1       AKT1-2    AKT1  0.799205     HCC44  cutting_control    pearson
# 2     ARID1B-1  ARID1B  0.425039     HCC44  cutting_control    pearson
# 3     ARID1B-2  ARID1B  0.310649     HCC44  cutting_control    pearson
# 4       ATF4-1    ATF4  0.231863     HCC44  cutting_control    pearson
#
#   compartment channel feature_group  num_features dropped_or_exclusive
# 0       Cells     all           all           100              dropped
# 1       Cells     all           all           100              dropped
# 2       Cells     all           all           100              dropped
# 3       Cells     all           all           100              dropped
# 4       Cells     all           all           100              dropped

# %%
# Output results
output_dir = "results"
output_file = pathlib.Path(f"{output_dir}/cell_health_grit_compartments.tsv.gz")

full_grit_results.to_csv(
    output_file,
    sep="\t",
    compression={"method": "gzip", "mtime": 1},
    index=False
)
