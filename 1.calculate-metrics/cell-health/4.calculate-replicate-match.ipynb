# %% [markdown]
# ## Calculate replicate matching

# %%
import pathlib
import numpy as np
import pandas as pd

from pycytominer.cyto_utils import infer_cp_features

from cytominer_eval import evaluate
from cytominer_eval.transform import metric_melt
from cytominer_eval.operations.util import assign_replicates

# %%
output_dir = "results"

file = pathlib.Path("data/cell_health_merged_feature_select.csv.gz")
cell_health_df = pd.read_csv(file)

print(cell_health_df.shape)
cell_health_df.head()
# Out:
# (3456, 402)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014618           A01                 1                A
# 1     SQ00014618           A02                 2                A
# 2     SQ00014618           A03                 3                A
# 3     SQ00014618           A04                 4                A
# 4     SQ00014618           A05                 5                A
#
#   Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0              HCC44              EMPTY              EMPTY
# 1              HCC44               MCL1             MCL1-5
# 2              HCC44               AKT1             AKT1-1
# 3              HCC44               KRAS            KRAS-2B
# 4              HCC44               AKT1             AKT1-2
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0                    -1.515696                0.810956
# 1                     0.246423                0.687241
# 2                     0.416772                0.151184
# 3                     0.645336               -0.290637
# 4                     0.159822                0.308919
#
#    Cells_AreaShape_Zernike_0_0  ...  \
# 0                     1.984031  ...
# 1                     0.062305  ...
# 2                    -0.045541  ...
# 3                    -0.455894  ...
# 4                    -0.195773  ...
#
#    Nuclei_Texture_InverseDifferenceMoment_Mito_5_0  \
# 0                                        -1.365392
# 1                                        -0.070069
# 2                                        -1.491414
# 3                                        -0.956379
# 4                                        -1.200222
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_10_0  \
# 0                                        -0.351107
# 1                                         1.855687
# 2                                         0.377266
# 3                                         0.116267
# 4                                         0.152902
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_20_0  \
# 0                                        -0.163153
# 1                                        -0.400335
# 2                                        -0.540338
# 3                                         0.338568
# 4                                        -0.833538
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumAverage_ER_5_0  \
# 0                           2.307568                         -2.775524
# 1                           3.776635                          0.947498
# 2                           1.743963                         -0.510880
# 3                           1.467339                         -0.749321
# 4                           2.129282                         -0.719243
#
#    Nuclei_Texture_SumAverage_Mito_20_0  Nuclei_Texture_SumAverage_RNA_5_0  \
# 0                            -3.951667                          -1.716353
# 1                            -0.541032                           0.363568
# 2                            -2.206918                          -1.440147
# 3                            -1.318064                          -1.466339
# 4                            -0.198956                          -0.702847
#
#    Nuclei_Texture_SumEntropy_ER_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                         -2.703082                           -3.720976
# 1                          0.910251                           -0.364015
# 2                         -0.571847                           -2.261104
# 3                         -1.060094                           -2.056278
# 4                         -1.291783                           -1.299857
#
#    Nuclei_Texture_SumEntropy_RNA_5_0
# 0                           0.107581
# 1                           0.165935
# 2                          -1.358338
# 3                          -0.975661
# 4                          -0.575835
#
# [5 rows x 402 columns]

# %%
features = infer_cp_features(cell_health_df)
meta_features = infer_cp_features(cell_health_df, metadata=True)

similarity_metric = "pearson"
operation = "replicate_reproducibility"

replicate_groups = ["Metadata_cell_line", "Metadata_gene_name", "Metadata_pert_name"]

control_ids = ["Chr2", "Luc", "LacZ"]

# %%
# Melt the input profiles to long format
similarity_melted_df = metric_melt(
    df=cell_health_df,
    features=features,
    metadata_features=meta_features,
    similarity_metric=similarity_metric,
    eval_metric=operation,
)

similarity_melted_df = assign_replicates(
    similarity_melted_df=similarity_melted_df, replicate_groups=replicate_groups
)

print(similarity_melted_df.shape)
similarity_melted_df.head()
# Out:
# (5970240, 21)
#   Metadata_Plate_pair_a Metadata_Well_pair_a Metadata_WellCol_pair_a  \
# 0            SQ00014618                  A01                       1
# 1            SQ00014618                  A01                       1
# 2            SQ00014618                  A01                       1
# 3            SQ00014618                  A01                       1
# 4            SQ00014618                  A01                       1
#
#   Metadata_WellRow_pair_a Metadata_cell_line_pair_a Metadata_gene_name_pair_a  \
# 0                       A                     HCC44                     EMPTY
# 1                       A                     HCC44                     EMPTY
# 2                       A                     HCC44                     EMPTY
# 3                       A                     HCC44                     EMPTY
# 4                       A                     HCC44                     EMPTY
#
#   Metadata_pert_name_pair_a Metadata_Plate_pair_b Metadata_Well_pair_b  \
# 0                     EMPTY            SQ00014618                  A02
# 1                     EMPTY            SQ00014618                  A03
# 2                     EMPTY            SQ00014618                  A04
# 3                     EMPTY            SQ00014618                  A05
# 4                     EMPTY            SQ00014618                  A06
#
#   Metadata_WellCol_pair_b  ... Metadata_cell_line_pair_b  \
# 0                       2  ...                     HCC44
# 1                       3  ...                     HCC44
# 2                       4  ...                     HCC44
# 3                       5  ...                     HCC44
# 4                       6  ...                     HCC44
#
#   Metadata_gene_name_pair_b Metadata_pert_name_pair_b pair_a_index  \
# 0                      MCL1                    MCL1-5            0
# 1                      AKT1                    AKT1-1            0
# 2                      KRAS                   KRAS-2B            0
# 3                      AKT1                    AKT1-2            0
# 4                     EMPTY                     EMPTY            0
#
#    pair_b_index similarity_metric  Metadata_cell_line_replicate  \
# 0             1          0.341360                          True
# 1             2          0.603323                          True
# 2             3          0.577072                          True
# 3             4          0.473938                          True
# 4             5          0.552049                          True
#
#    Metadata_gene_name_replicate  Metadata_pert_name_replicate  group_replicate
# 0                         False                         False            False
# 1                         False                         False            False
# 2                         False                         False            False
# 3                         False                         False            False
# 4                          True                          True             True
#
# [5 rows x 21 columns]

# %%
non_replicate_cor_95th = (
    similarity_melted_df.query("not group_replicate")
    .groupby("Metadata_cell_line_pair_a")["similarity_metric"]
    .quantile(0.95)
    .reset_index()
    .rename({"Metadata_cell_line_pair_a": "cell_line"}, axis="columns")
)

# Output results
output_file = pathlib.Path(f"{output_dir}/cell_health_nonreplicate_95thpercentile.tsv")

non_replicate_cor_95th.to_csv(output_file, sep="\t", index=False)
non_replicate_cor_95th
# Out:
#   cell_line  similarity_metric
# 0      A549           0.528442
# 1       ES2           0.502821
# 2     HCC44           0.458500

# %%
# Capture median replicate correlation
median_replicate_correlation_df = (
    similarity_melted_df.query("group_replicate")
    .groupby(
        [
            "Metadata_cell_line_pair_a",
            "Metadata_gene_name_pair_a",
            "Metadata_pert_name_pair_a",
        ]
    )["similarity_metric"]
    .median()
    .reset_index()
    .rename(
        {
            "similarity_metric": "median_replicate_correlation",
            "Metadata_pert_name_pair_a": "perturbation",
            "Metadata_gene_name_pair_a": "group",
            "Metadata_cell_line_pair_a": "cell_line",
        },
        axis="columns",
    )
)

print(median_replicate_correlation_df.shape)
median_replicate_correlation_df.head()
# Out:
# (357, 4)
#   cell_line   group perturbation  median_replicate_correlation
# 0      A549    AKT1       AKT1-1                      0.022261
# 1      A549    AKT1       AKT1-2                     -0.302957
# 2      A549  ARID1B     ARID1B-1                      0.311278
# 3      A549  ARID1B     ARID1B-2                      0.405716
# 4      A549    ATF4       ATF4-1                      0.821153

# %%
median_empty_correlation_df = (
    similarity_melted_df.query("Metadata_gene_name_pair_b in @control_ids")
    .groupby(
        [
            "Metadata_cell_line_pair_a",
            "Metadata_gene_name_pair_a",
            "Metadata_pert_name_pair_a",
        ]
    )["similarity_metric"]
    .median()
    .reset_index()
    .rename(
        {
            "similarity_metric": "median_control_correlation",
            "Metadata_pert_name_pair_a": "perturbation",
            "Metadata_gene_name_pair_a": "group",
            "Metadata_cell_line_pair_a": "cell_line",
        },
        axis="columns",
    )
)

print(median_empty_correlation_df.shape)
median_empty_correlation_df.head()
# Out:
# (357, 4)
#   cell_line   group perturbation  median_control_correlation
# 0      A549    AKT1       AKT1-1                    0.016903
# 1      A549    AKT1       AKT1-2                    0.002390
# 2      A549  ARID1B     ARID1B-1                    0.027581
# 3      A549  ARID1B     ARID1B-2                    0.062314
# 4      A549    ATF4       ATF4-1                    0.081103

# %%
full_correlation_results_df = median_replicate_correlation_df.merge(
    median_empty_correlation_df, on=["cell_line", "group", "perturbation"], how="inner"
)

print(full_correlation_results_df.shape)
full_correlation_results_df.head()
# Out:
# (357, 5)
#   cell_line   group perturbation  median_replicate_correlation  \
# 0      A549    AKT1       AKT1-1                      0.022261
# 1      A549    AKT1       AKT1-2                     -0.302957
# 2      A549  ARID1B     ARID1B-1                      0.311278
# 3      A549  ARID1B     ARID1B-2                      0.405716
# 4      A549    ATF4       ATF4-1                      0.821153
#
#    median_control_correlation
# 0                    0.016903
# 1                    0.002390
# 2                    0.027581
# 3                    0.062314
# 4                    0.081103

# %%
# Output results
output_file = pathlib.Path(f"{output_dir}/cell_health_replicate_reproducibility.tsv")

full_correlation_results_df.to_csv(output_file, sep="\t", index=False)
