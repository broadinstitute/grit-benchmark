# %% [markdown]
# # Build consensus signatures (1 signature for each CRISPR guide) from bulk profiles for Cell Health prediction pipeline
# **Generate consensus signatures with median + moderated-z-score**
#
# Consensus-profiles are generated via:
# MODZ (moderated z-score)
#
# *reference: cell-health/1.generate-profiles/2.build-consensus-signatures*

# %%
import os
import glob
import gzip
from pathlib import Path
import pickle
import re

import numpy as np
import pandas as pd

from pycytominer.consensus import modz
from pycytominer import get_na_columns, aggregate

# from scipy.special import softmax 

from pycytominer import aggregate
from pycytominer.cyto_utils import infer_cp_features
from scripts.utils import calculate_weighted_agg

# %% [markdown]
# ## Load Cell Painting Data
# These are individual df's pf well-level profiles (level 3) that are concatatenated into a single file per aggregation method.

# %%
input_folder = 'data/processed/'
output_folder = 'data/profiles/'
method_list = list(set([(x.split("_")[1:][0]).split('.')[0] for x in glob.glob(input_folder+'*.tsv')]))

# since single-cell grit was not calculated for EMPTY wells, we will use median-aggregated well-level profiles 
# for EMPTY perturbations to form the EMPTY consensus profile for the cell health prediction pipeline
empty_list = []
for file in glob.glob(input_folder+'*.tsv'):
    file_cell_line = file.split('/')[-1].split('.')[0].split('_')[0]
    file_method = file.split('/')[-1].split('.')[0].split('_')[1]
    if "EMPTY" in file:
        print(f"adding {file} to list")
        empties_df = (pd.read_csv(file,sep='\t')
                      .assign(Metadata_cellline = file_cell_line, 
                              Metadata_aggmethod = file_method)
                           )
        empty_list.append(empties_df)
#     print(file.split('/')[-1].split('.')[0].split('_')[1])
empty_profiles = pd.concat(empty_list)
empty_profiles = empty_profiles[sorted(empty_profiles, key = lambda x: x not in empty_profiles.filter(like="Metadata").columns)]
print("total shape: ", empty_profiles.shape)
display(empty_profiles.head())


# perform for both well-level aggregation methods (median and grit-informed)
for method in method_list:# ['weighted']: # 
    print(f"for method is: {method}")
    df_list = []
    for file in glob.glob(input_folder+'*.tsv'):
        file_cell_line = file.split('/')[-1].split('.')[0].split('_')[0]
        file_method = file.split('/')[-1].split('.')[0].split('_')[1]
        if method in file and "EMPTY" not in file:
            print(f"adding {file} to {method} df")
            cell_line_df = (pd.read_csv(file,sep='\t')
                            .assign(Metadata_cellline = file_cell_line, Metadata_aggmethod = file_method)
                           )
            df_list.append(cell_line_df)        
    level3profiles = pd.concat(df_list, axis='rows')
    # add in the EMPTY wells
    level3profiles = pd.concat([level3profiles, empty_profiles], axis='rows')
    # reorder the columns
    level3profiles = level3profiles[sorted(level3profiles, key = lambda x: x not in level3profiles.filter(like="Metadata").columns)]
    print(level3profiles.shape)
    display(level3profiles.head())
    print(infer_cp_features(level3profiles, metadata=True))
    
    # Output final merged file (for all cell lines)
    filename = Path(f"{output_folder}cell_health_profiles_{method}_merged.tsv.gz")
    print(f"filename will be: {filename}")
    level3profiles.to_csv(filename, index=False, sep='\t')
# Out:
# adding data/processed/ES2_median_EMPTY.tsv to list
# adding data/processed/HCC44_median_EMPTY.tsv to list
# adding data/processed/A549_median_EMPTY.tsv to list
# /home/ubuntu/miniconda3/envs/cell-health/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# total shape:  (504, 956)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014613           A01                 1                A
# 1     SQ00014614           A01                 1                A
# 2     SQ00014615           A01                 1                A
# 3     SQ00014613           A06                 6                A
# 4     SQ00014614           A06                 6                A
#
#   Metadata_agg_method Metadata_aggmethod  Metadata_broad_sample  \
# 0              median             median                    NaN
# 1              median             median                    NaN
# 2              median             median                    NaN
# 3              median             median                    NaN
# 4              median             median                    NaN
#
#   Metadata_cell_line Metadata_cellline Metadata_gene_name  ...  \
# 0                ES2               ES2              EMPTY  ...
# 1                ES2               ES2              EMPTY  ...
# 2                ES2               ES2              EMPTY  ...
# 3                ES2               ES2              EMPTY  ...
# 4                ES2               ES2              EMPTY  ...
#
#   Nuclei_Texture_SumVariance_AGP_20_0 Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                           -0.318050                          -0.221235
# 1                           -0.091395                          -0.082155
# 2                           -0.189930                          -0.164470
# 3                           -0.175730                          -0.167350
# 4                            0.023310                           0.045275
#
#    Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_20_0  \
# 0                             0.069430                            -0.050265
# 1                            -0.272640                            -0.230890
# 2                            -0.327750                            -0.305840
# 3                             0.002420                            -0.054990
# 4                             0.158715                             0.073295
#
#    Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                            0.151535                         -0.20523
# 1                           -0.230420                         -0.04145
# 2                           -0.292030                         -0.09400
# 3                            0.046540                         -0.14455
# 4                            0.195675                          0.08258
#
#    Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_20_0  \
# 0                          0.159450                          0.131155
# 1                         -0.236835                         -0.189550
# 2                         -0.245880                         -0.216980
# 3                          0.009760                          0.000300
# 4                          0.144725                          0.143755
#
#    Nuclei_Texture_Variance_DNA_5_0  cell_line
# 0                         0.155930        ES2
# 1                        -0.232285        ES2
# 2                        -0.270280        ES2
# 3                         0.023730        ES2
# 4                         0.165670        ES2
#
# [5 rows x 956 columns]
# for method is: median
# adding data/processed/ES2_median.tsv to median df
# adding data/processed/HCC44_median.tsv to median df
# adding data/processed/A549_median.tsv to median df
# /home/ubuntu/miniconda3/envs/cell-health/lib/python3.7/site-packages/ipykernel_launcher.py:38: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# /home/ubuntu/miniconda3/envs/cell-health/lib/python3.7/site-packages/ipykernel_launcher.py:40: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# (3456, 956)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014613           A02                 2                A
# 1     SQ00014614           A02                 2                A
# 2     SQ00014615           A02                 2                A
# 3     SQ00014613           A03                 3                A
# 4     SQ00014614           A03                 3                A
#
#   Metadata_agg_method Metadata_aggmethod Metadata_broad_sample  \
# 0              median             median                   NaN
# 1              median             median                   NaN
# 2              median             median                   NaN
# 3              median             median        BRDN0001054908
# 4              median             median        BRDN0001054908
#
#   Metadata_cell_line Metadata_cellline Metadata_gene_name  ...  \
# 0                ES2               ES2               MCL1  ...
# 1                ES2               ES2               MCL1  ...
# 2                ES2               ES2               MCL1  ...
# 3                ES2               ES2               AKT1  ...
# 4                ES2               ES2               AKT1  ...
#
#   Nuclei_Texture_SumVariance_AGP_20_0 Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                            0.046700                           0.172430
# 1                            0.253650                           0.282630
# 2                           -0.183780                          -0.172340
# 3                            0.119705                           0.265515
# 4                            0.069540                           0.131370
#
#    Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_20_0  \
# 0                             0.266465                             0.091205
# 1                             0.122200                             0.067950
# 2                            -0.366350                            -0.327890
# 3                             0.570185                             0.312945
# 4                             0.122380                             0.096320
#
#    Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                            0.323115                         0.225055
# 1                            0.150790                         0.323810
# 2                           -0.342530                        -0.110560
# 3                            0.653030                         0.250780
# 4                            0.151730                         0.145890
#
#    Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_20_0  \
# 0                          0.297500                          0.261055
# 1                          0.113770                          0.130460
# 2                         -0.288690                         -0.236750
# 3                          0.644895                          0.611595
# 4                          0.119430                          0.119500
#
#    Nuclei_Texture_Variance_DNA_5_0  cell_line
# 0                          0.31938        ES2
# 1                          0.12595        ES2
# 2                         -0.31655        ES2
# 3                          0.64429        ES2
# 4                          0.12892        ES2
#
# [5 rows x 956 columns]
# ['Metadata_Plate', 'Metadata_Well', 'Metadata_WellCol', 'Metadata_WellRow', 'Metadata_agg_method', 'Metadata_aggmethod', 'Metadata_broad_sample', 'Metadata_cell_line', 'Metadata_cellline', 'Metadata_gene_name', 'Metadata_pert_name', 'Metadata_well_position']
# filename will be: data/profiles/cell_health_profiles_median_merged.tsv.gz
# for method is: weighted
# adding data/processed/A549_weighted.tsv to weighted df
# adding data/processed/HCC44_weighted.tsv to weighted df
# adding data/processed/ES2_weighted.tsv to weighted df
# (3456, 956)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014610           A02                 2                A
# 1     SQ00014611           A02                 2                A
# 2     SQ00014612           A02                 2                A
# 3     SQ00014610           A03                 3                A
# 4     SQ00014611           A03                 3                A
#
#   Metadata_agg_method Metadata_aggmethod Metadata_broad_sample  \
# 0            weighted           weighted                   NaN
# 1            weighted           weighted                   NaN
# 2            weighted           weighted                   NaN
# 3            weighted           weighted        BRDN0001054908
# 4            weighted           weighted        BRDN0001054908
#
#   Metadata_cell_line Metadata_cellline Metadata_gene_name  ...  \
# 0               A549              A549               MCL1  ...
# 1               A549              A549               MCL1  ...
# 2               A549              A549               MCL1  ...
# 3               A549              A549               AKT1  ...
# 4               A549              A549               AKT1  ...
#
#   Nuclei_Texture_SumVariance_AGP_20_0 Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                            1.284069                           1.362209
# 1                            0.344570                           0.509215
# 2                            0.249964                           0.409406
# 3                            0.370862                           0.286531
# 4                            0.149827                           0.280987
#
#    Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_20_0  \
# 0                             1.003097                             0.676481
# 1                             0.296711                             0.005066
# 2                             0.022137                            -0.109076
# 3                             0.098980                             0.056056
# 4                             0.228706                             0.041776
#
#    Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                            1.083978                         1.319537
# 1                            0.433841                         0.511761
# 2                            0.093917                         0.457390
# 3                            0.121362                         0.277774
# 4                            0.307017                         0.264183
#
#    Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_20_0  \
# 0                          1.112346                          1.151328
# 1                          0.551234                          0.477705
# 2                          0.215358                          0.172091
# 3                          0.137682                          0.218140
# 4                          0.361494                          0.295622
#
#    Nuclei_Texture_Variance_DNA_5_0  cell_line
# 0                         1.084761       A549
# 1                         0.518965       A549
# 2                         0.164175       A549
# 3                         0.130580       A549
# 4                         0.352904       A549
#
# [5 rows x 956 columns]
# ['Metadata_Plate', 'Metadata_Well', 'Metadata_WellCol', 'Metadata_WellRow', 'Metadata_agg_method', 'Metadata_aggmethod', 'Metadata_broad_sample', 'Metadata_cell_line', 'Metadata_cellline', 'Metadata_gene_name', 'Metadata_pert_name', 'Metadata_well_position']
# filename will be: data/profiles/cell_health_profiles_weighted_merged.tsv.gz

# %% [markdown]
# ## Build Consensus Signatures for aggregation methods
# The remainder of this script generates consensus signatures (1 signature for each CRISPR guide perturbation). The remaining cells are
# 1. ...run once with `method='weighted'` to generate consensus signatures using grit-weighted aggregation of single-cell profiles into well-level profiles
# 2. ...run again with `method='median'` to generate consensus signatures using standard median aggregation of single-cells profiles into well-level profiles

# %% [markdown]
# ### Read in well-level profiles

# %%
folder = 'data/profiles/'
method='weighted'
# method='median'

# %%
x_df = pd.read_csv(Path(f"{folder}cell_health_profiles_{method}_merged.tsv.gz"), sep='\t', low_memory=False)
print(x_df.shape)
display(x_df.head())
x_df.groupby(['Metadata_cell_line']).apply(lambda x: len(get_na_columns(x)))
# Out:
# (3456, 956)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014610           A02                 2                A
# 1     SQ00014611           A02                 2                A
# 2     SQ00014612           A02                 2                A
# 3     SQ00014610           A03                 3                A
# 4     SQ00014611           A03                 3                A
#
#   Metadata_agg_method Metadata_aggmethod Metadata_broad_sample  \
# 0            weighted           weighted                   NaN
# 1            weighted           weighted                   NaN
# 2            weighted           weighted                   NaN
# 3            weighted           weighted        BRDN0001054908
# 4            weighted           weighted        BRDN0001054908
#
#   Metadata_cell_line Metadata_cellline Metadata_gene_name  ...  \
# 0               A549              A549               MCL1  ...
# 1               A549              A549               MCL1  ...
# 2               A549              A549               MCL1  ...
# 3               A549              A549               AKT1  ...
# 4               A549              A549               AKT1  ...
#
#   Nuclei_Texture_SumVariance_AGP_20_0 Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                            1.284069                           1.362209
# 1                            0.344570                           0.509215
# 2                            0.249964                           0.409406
# 3                            0.370862                           0.286531
# 4                            0.149827                           0.280987
#
#    Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_20_0  \
# 0                             1.003097                             0.676481
# 1                             0.296711                             0.005066
# 2                             0.022137                            -0.109076
# 3                             0.098980                             0.056056
# 4                             0.228706                             0.041776
#
#    Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                            1.083978                         1.319537
# 1                            0.433841                         0.511761
# 2                            0.093917                         0.457390
# 3                            0.121362                         0.277774
# 4                            0.307017                         0.264183
#
#    Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_20_0  \
# 0                          1.112346                          1.151328
# 1                          0.551234                          0.477705
# 2                          0.215358                          0.172091
# 3                          0.137682                          0.218140
# 4                          0.361494                          0.295622
#
#    Nuclei_Texture_Variance_DNA_5_0  cell_line
# 0                         1.084761       A549
# 1                         0.518965       A549
# 2                         0.164175       A549
# 3                         0.130580       A549
# 4                         0.352904       A549
#
# [5 rows x 956 columns]
# Metadata_cell_line
# A549     14
# ES2      15
# HCC44    21
# dtype: int64

# %% [markdown]
# ### Load Cell Health labels from cell-health/ project

# %%
commit = "8244680d6e6db1a2bc1f709b9dabf7783c4a9670"
base_url = f"https://github.com/broadinstitute/cell-health/raw/{commit}"
url = f"{base_url}/1.generate-profiles/data/labels/normalized_cell_health_labels.tsv"

y_df = pd.read_csv(url, sep='\t').drop(["plate_name", "well_col", "well_row"], axis="columns")

print(y_df.shape)
y_df.head(3)
# Out:
# (2302, 72)
#   cell_id   guide  cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# 0     ES2  AKT1-1          0.655229                               -0.565658
# 1     ES2  AKT1-1         -0.251336                               -0.816445
# 2     ES2  AKT1-1          0.338568                               -0.683965
#
#    cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# 0                          -0.839186         -0.513748
# 1                          -0.525940         -0.819810
# 2                           0.934312          0.292330
#
#    cc_all_n_spots_h2ax_mean  cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# 0                  0.313600                                   0.263062
# 1                 -0.450799                                  -0.811628
# 2                  0.272986                                  -0.007936
#
#    cc_all_nucleus_area_mean  cc_all_nucleus_roundness_mean  ...  \
# 0                  0.109983                      -0.226513  ...
# 1                 -0.468875                      -0.167787  ...
# 2                  0.083732                       0.051220  ...
#
#    vb_num_live_cells  vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# 0           0.281397                 -0.279051                     -0.920300
# 1           0.543716                 -0.221588                     -1.070176
# 2          -0.472052                 -0.053067                      0.098093
#
#    vb_percent_dead  vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0        -0.139875             -0.016549                   -0.429141
# 1        -0.046783              0.268559                   -0.311041
# 2        -0.038353             -0.161186                   -0.127101
#
#    vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                  -0.177258         0.140570               NaN          NaN
# 1                  -0.149198         0.040163          -0.29248     0.008339
# 2                  -0.014996         0.038221               NaN          NaN
#
# [3 rows x 72 columns]

# %% [markdown]
# ## Determine how many Cell Painting profiles have Cell Health status labels

# %%
x_groupby_cols = ["Metadata_gene_name", "Metadata_pert_name", "Metadata_cell_line"]

x_metacount_df = (
    x_df
    .loc[:, x_groupby_cols]
    .assign(n_measurements=1)
    .groupby(x_groupby_cols)
    .count()
    .reset_index()
    .assign(data_type="cell_painting")
    .merge(x_df.loc[:, x_groupby_cols + ["Metadata_Well", "Metadata_Plate"]],
           how="left",
           on=x_groupby_cols)
)

print(x_metacount_df.shape)
x_metacount_df.head(2)
# Out:
# (3456, 7)
#   Metadata_gene_name Metadata_pert_name Metadata_cell_line  n_measurements  \
# 0               AKT1             AKT1-1               A549               6
# 1               AKT1             AKT1-1               A549               6
#
#        data_type Metadata_Well Metadata_Plate
# 0  cell_painting           A03     SQ00014610
# 1  cell_painting           A03     SQ00014611

# %%
# cell health labels
y_groupby_cols = ["guide", "cell_id"]

y_metacount_df = (
    y_df
    .loc[:, y_groupby_cols]
    .assign(n_measurements=1)
    .groupby(y_groupby_cols)
    .count()
    .reset_index()
    .assign(data_type="cell_health")
)

print(y_metacount_df.shape)
y_metacount_df.head(2)
# Out:
# (364, 4)
#     guide cell_id  n_measurements    data_type
# 0  AKT1-1    A549               4  cell_health
# 1  AKT1-1     ES2               4  cell_health

# %%
all_measurements_df = (
    x_metacount_df
    .merge(
        y_metacount_df,
        left_on=["Metadata_pert_name", "Metadata_cell_line"],
        right_on=["guide", "cell_id"],
        suffixes=["_paint", "_health"],
        how="inner")
    .sort_values(by=["Metadata_cell_line", "Metadata_pert_name"])
    .reset_index(drop=True)
    .drop(["Metadata_Well", "guide", "cell_id"], axis="columns")
)

file = os.path.join("results", "all_profile_metadata.tsv")
# all_measurements_df.to_csv(file, sep='\t', index=False)

print(all_measurements_df.shape)
all_measurements_df.head()
# Out:
# (3456, 8)
#   Metadata_gene_name Metadata_pert_name Metadata_cell_line  \
# 0               AKT1             AKT1-1               A549
# 1               AKT1             AKT1-1               A549
# 2               AKT1             AKT1-1               A549
# 3               AKT1             AKT1-1               A549
# 4               AKT1             AKT1-1               A549
#
#    n_measurements_paint data_type_paint Metadata_Plate  n_measurements_health  \
# 0                     6   cell_painting     SQ00014610                      4
# 1                     6   cell_painting     SQ00014611                      4
# 2                     6   cell_painting     SQ00014612                      4
# 3                     6   cell_painting     SQ00014610                      4
# 4                     6   cell_painting     SQ00014611                      4
#
#   data_type_health
# 0      cell_health
# 1      cell_health
# 2      cell_health
# 3      cell_health
# 4      cell_health

# %%
[len(all_measurements_df[x].unique()) for x in all_measurements_df.columns]
# Out:
# [59, 119, 3, 6, 1, 9, 8, 1]

# %%
[len(all_measurements_df[x].unique()) for x in all_measurements_df.columns]
# Out:
# [59, 119, 3, 6, 1, 9, 8, 1]

# %% [markdown]
# # apply median consensus aggregation...
# since the modz didnt work initially

# %% [markdown]
# ### 1. to Cell Painting Profiles

# %%
x_median_df = aggregate(
    x_df,
    strata=["Metadata_cell_line", "Metadata_pert_name"],
    features="infer",
    operation="median"
)

x_median_df = (
    x_median_df
    .query("Metadata_pert_name in @all_measurements_df.Metadata_pert_name.unique()")
    .query("Metadata_cell_line in @all_measurements_df.Metadata_cell_line.unique()")
    .reset_index(drop=True)
    .reset_index()
    .rename({"index": "Metadata_profile_id"}, axis='columns')
)
x_median_df.Metadata_profile_id = ["profile_{}".format(x) for x in x_median_df.Metadata_profile_id]

print(x_median_df.shape)
x_median_df.head()
# Out:
# (357, 946)
#   Metadata_profile_id Metadata_cell_line Metadata_pert_name  \
# 0           profile_0               A549             AKT1-1
# 1           profile_1               A549             AKT1-2
# 2           profile_2               A549           ARID1B-1
# 3           profile_3               A549           ARID1B-2
# 4           profile_4               A549             ATF4-1
#
#    Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                  0.242064                     0.026447
# 1                  0.034776                    -0.066228
# 2                 -0.117420                     0.224212
# 3                  0.042407                     0.254648
# 4                 -0.003576                    -0.071212
#
#    Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# 0                     -0.163592               -0.094232
# 1                     -0.020002                0.069651
# 2                      0.143370               -0.254822
# 3                      0.124658               -0.300156
# 4                     -0.045842                0.142506
#
#    Cells_AreaShape_Orientation  Cells_AreaShape_Zernike_0_0  \
# 0                    -0.020648                    -0.012759
# 1                    -0.008441                     0.085545
# 2                     0.038828                    -0.225436
# 3                     0.023645                    -0.209193
# 4                     0.023086                    -0.006711
#
#    Cells_AreaShape_Zernike_1_1  ...  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                     0.059713  ...                           0.468986
# 1                     0.113848  ...                           0.136530
# 2                     0.024631  ...                          -0.265539
# 3                     0.065093  ...                           0.159614
# 4                    -0.002751  ...                          -0.042162
#
#    Nuclei_Texture_SumVariance_AGP_20_0  Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                             0.524497                            0.832409
# 1                             0.265044                            0.380289
# 2                            -0.674021                           -0.726375
# 3                            -0.432893                           -0.480478
# 4                             0.116233                            0.001200
#
#    Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_20_0  \
# 0                             0.715932                             0.225928
# 1                             0.299140                            -0.052063
# 2                            -0.743734                            -0.665494
# 3                            -0.072464                            -0.125200
# 4                             0.088496                             0.196083
#
#    Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                            0.909484                         0.810709
# 1                            0.446032                         0.392730
# 2                           -0.820750                        -0.661084
# 3                           -0.000501                        -0.523288
# 4                            0.048844                        -0.026882
#
#    Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_20_0  \
# 0                          0.879704                          0.856938
# 1                          0.614219                          0.575369
# 2                         -0.627315                         -0.633939
# 3                         -0.042473                         -0.022650
# 4                         -0.069674                         -0.011722
#
#    Nuclei_Texture_Variance_DNA_5_0
# 0                         0.888772
# 1                         0.560667
# 2                        -0.701475
# 3                         0.013072
# 4                        -0.011095
#
# [5 rows x 946 columns]

# %%
# Output Profile Mapping for Downstream Analysis
profile_id_mapping_df = x_median_df.loc[:, x_median_df.columns.str.startswith("Metadata")]
file = os.path.join("data", "{}_profile_id_metadata_mapping.tsv".format(method))
print(file)
profile_id_mapping_df.to_csv(file, sep='\t', index=False)

print(profile_id_mapping_df.shape)
profile_id_mapping_df.head()
# Out:
# data/weighted_profile_id_metadata_mapping.tsv
# (357, 3)
#   Metadata_profile_id Metadata_cell_line Metadata_pert_name
# 0           profile_0               A549             AKT1-1
# 1           profile_1               A549             AKT1-2
# 2           profile_2               A549           ARID1B-1
# 3           profile_3               A549           ARID1B-2
# 4           profile_4               A549             ATF4-1

# %% [markdown]
# ### 2. to Cell Health Panel readouts

# %%
cell_health_meta_features = ["cell_id", "guide"]
cell_health_features = y_df.drop(cell_health_meta_features, axis="columns").columns.tolist()
y_meta_merge_cols = ["Metadata_profile_id", "Metadata_pert_name", "Metadata_cell_line"]

# %%
y_median_df = aggregate(
    y_df,
    strata=cell_health_meta_features,
    features=cell_health_features,
    operation="median"
)

print(y_median_df.shape)
y_median_df.head()
# Out:
# (364, 72)
#   cell_id     guide  cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# 0    A549    AKT1-1          0.008156                                0.587977
# 1    A549    AKT1-2          0.056667                                1.264627
# 2    A549  ARID1B-1          0.111163                                1.092964
# 3    A549  ARID1B-2         -0.061528                                0.320829
# 4    A549    ATF4-1          3.967818                                0.003400
#
#    cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# 0                           0.018820          0.381501
# 1                           0.241450          0.568443
# 2                           0.151393          0.290203
# 3                          -0.091007          0.141819
# 4                           3.268615         -2.246887
#
#    cc_all_n_spots_h2ax_mean  cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# 0                  0.176564                                   0.187675
# 1                  0.235304                                   0.372684
# 2                  0.402121                                   0.481700
# 3                 -0.378769                                  -0.288693
# 4                  2.891737                                   2.878938
#
#    cc_all_nucleus_area_mean  cc_all_nucleus_roundness_mean  ...  \
# 0                 -0.170616                       0.039147  ...
# 1                 -0.276888                      -0.183445  ...
# 2                 -0.276980                      -0.149979  ...
# 3                 -0.108741                      -0.300783  ...
# 4                  2.853995                       1.243444  ...
#
#    vb_num_live_cells  vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# 0           0.399842                  0.000000                     -0.118976
# 1           0.101670                  0.318027                      0.621374
# 2           0.080701                  0.339100                      0.598093
# 3           0.265754                  0.098699                      0.371930
# 4          -2.343919                  0.000000                     -0.089544
#
#    vb_percent_dead  vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0        -0.132871             -0.121090                    0.000000
# 1         0.100032              0.074036                    0.132751
# 2         0.055951              0.042014                    0.165161
# 3        -0.063935             -0.055160                    0.138654
# 4         0.141535              0.131393                    0.000000
#
#    vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                   0.000000         0.132882          0.806970     1.293984
# 1                   0.467027        -0.099917          0.558041     1.151867
# 2                   0.247058        -0.055920         -0.393937     0.103202
# 3                   0.000000         0.063946          0.210005     0.055291
# 4                   0.000000        -0.141397         -0.631390     0.106477
#
# [5 rows x 72 columns]

# %%
y_median_df = (
    y_median_df
    .reset_index(drop=True)
    .merge(
        x_median_df.loc[:, y_meta_merge_cols],
        left_on=["guide", "cell_id"],
        right_on=["Metadata_pert_name", "Metadata_cell_line"],
        how="right"
    )
)

# Get columns in correct order
y_columns = (
    y_meta_merge_cols +
    y_median_df
    .loc[:, ~y_median_df.columns.str.startswith("Metadata_")]
    .columns
    .tolist()
)

y_median_df = (
    y_median_df
    .loc[:, y_columns]
    .drop(["guide", "cell_id"], axis="columns")
)

print(y_median_df.shape)
y_median_df.head(5)
# Out:
# (357, 73)
#   Metadata_profile_id Metadata_pert_name Metadata_cell_line  cc_all_high_h2ax  \
# 0           profile_0             AKT1-1               A549          0.008156
# 1           profile_1             AKT1-2               A549          0.056667
# 2           profile_2           ARID1B-1               A549          0.111163
# 3           profile_3           ARID1B-2               A549         -0.061528
# 4           profile_4             ATF4-1               A549          3.967818
#
#    cc_all_large_notround_polynuclear_mean  cc_all_large_round_polyploid_mean  \
# 0                                0.587977                           0.018820
# 1                                1.264627                           0.241450
# 2                                1.092964                           0.151393
# 3                                0.320829                          -0.091007
# 4                                0.003400                           3.268615
#
#    cc_all_n_objects  cc_all_n_spots_h2ax_mean  \
# 0          0.381501                  0.176564
# 1          0.568443                  0.235304
# 2          0.290203                  0.402121
# 3          0.141819                 -0.378769
# 4         -2.246887                  2.891737
#
#    cc_all_n_spots_h2ax_per_nucleus_area_mean  cc_all_nucleus_area_mean  ...  \
# 0                                   0.187675                 -0.170616  ...
# 1                                   0.372684                 -0.276888  ...
# 2                                   0.481700                 -0.276980  ...
# 3                                  -0.288693                 -0.108741  ...
# 4                                   2.878938                  2.853995  ...
#
#    vb_num_live_cells  vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# 0           0.399842                  0.000000                     -0.118976
# 1           0.101670                  0.318027                      0.621374
# 2           0.080701                  0.339100                      0.598093
# 3           0.265754                  0.098699                      0.371930
# 4          -2.343919                  0.000000                     -0.089544
#
#    vb_percent_dead  vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0        -0.132871             -0.121090                    0.000000
# 1         0.100032              0.074036                    0.132751
# 2         0.055951              0.042014                    0.165161
# 3        -0.063935             -0.055160                    0.138654
# 4         0.141535              0.131393                    0.000000
#
#    vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                   0.000000         0.132882          0.806970     1.293984
# 1                   0.467027        -0.099917          0.558041     1.151867
# 2                   0.247058        -0.055920         -0.393937     0.103202
# 3                   0.000000         0.063946          0.210005     0.055291
# 4                   0.000000        -0.141397         -0.631390     0.106477
#
# [5 rows x 73 columns]

# %%
# Confirm that matrices are aligned

pd.testing.assert_series_equal(
    x_median_df.Metadata_profile_id,
    y_median_df.Metadata_profile_id,
    check_names=True
)

# Are the guides aligned?
pd.testing.assert_series_equal(
    x_median_df.Metadata_pert_name,
    y_median_df.Metadata_pert_name,
    check_names=True
)

# Are the cells aligned?
pd.testing.assert_series_equal(
    x_median_df.Metadata_cell_line,
    y_median_df.Metadata_cell_line,
    check_names=True
)

# %% [markdown]
# # apply MODZ consensus aggregation

# %% [markdown]
# ### ...to Cell Painting Profiles

# %%
# %%time

x_consensus_df = modz(
    x_df,
    replicate_columns=["Metadata_cell_line", "Metadata_pert_name"],
    precision=5
)

x_consensus_df.head()
# Out:
# CPU times: user 19.2 s, sys: 35.2 ms, total: 19.2 s
# Wall time: 19.2 s
#                                        Cells_AreaShape_Center_Y  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                              0.503175
#                    AKT1-2                              0.100797
#                    ARID1B-1                           -0.130649
#                    ARID1B-2                            0.084150
#                    ATF4-1                              0.010101
#
#                                        Cells_AreaShape_Compactness  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                 0.110106
#                    AKT1-2                                -0.101499
#                    ARID1B-1                               0.448408
#                    ARID1B-2                               0.552944
#                    ATF4-1                                -0.079724
#
#                                        Cells_AreaShape_Eccentricity  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                 -0.045764
#                    AKT1-2                                 -0.052097
#                    ARID1B-1                                0.292884
#                    ARID1B-2                                0.326113
#                    ATF4-1                                 -0.053684
#
#                                        Cells_AreaShape_Extent  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                           -0.263006
#                    AKT1-2                           -0.010985
#                    ARID1B-1                         -0.412305
#                    ARID1B-2                         -0.610228
#                    ATF4-1                            0.125938
#
#                                        Cells_AreaShape_Orientation  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                -0.070482
#                    AKT1-2                                -0.012921
#                    ARID1B-1                               0.035924
#                    ARID1B-2                               0.033123
#                    ATF4-1                                 0.022919
#
#                                        Cells_AreaShape_Zernike_0_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                -0.062049
#                    AKT1-2                                 0.125160
#                    ARID1B-1                              -0.428059
#                    ARID1B-2                              -0.561141
#                    ATF4-1                                 0.019611
#
#                                        Cells_AreaShape_Zernike_1_1  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                 0.183216
#                    AKT1-2                                 0.162637
#                    ARID1B-1                               0.025479
#                    ARID1B-2                               0.100766
#                    ATF4-1                                 0.002694
#
#                                        Cells_AreaShape_Zernike_2_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                -0.215126
#                    AKT1-2                                -0.063450
#                    ARID1B-1                              -0.303993
#                    ARID1B-2                              -0.406873
#                    ATF4-1                                 0.092245
#
#                                        Cells_AreaShape_Zernike_2_2  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                -0.088522
#                    AKT1-2                                 0.039013
#                    ARID1B-1                               0.125645
#                    ARID1B-2                               0.058547
#                    ATF4-1                                -0.095388
#
#                                        Cells_AreaShape_Zernike_3_3  ...  \
# Metadata_cell_line Metadata_pert_name                               ...
# A549               AKT1-1                                 0.191404  ...
#                    AKT1-2                                 0.057876  ...
#                    ARID1B-1                               0.054173  ...
#                    ARID1B-2                               0.117841  ...
#                    ATF4-1                                -0.066832  ...
#
#                                        Nuclei_Texture_SumEntropy_RNA_5_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                       0.774055
#                    AKT1-2                                       0.406455
#                    ARID1B-1                                    -0.281958
#                    ARID1B-2                                     0.093125
#                    ATF4-1                                      -0.044726
#
#                                        Nuclei_Texture_SumVariance_AGP_20_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                         1.033896
#                    AKT1-2                                         0.367872
#                    ARID1B-1                                      -0.785849
#                    ARID1B-2                                      -0.469950
#                    ATF4-1                                         0.151566
#
#                                        Nuclei_Texture_SumVariance_AGP_5_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                        1.433717
#                    AKT1-2                                        0.598358
#                    ARID1B-1                                     -0.795507
#                    ARID1B-2                                     -0.650276
#                    ATF4-1                                        0.048038
#
#                                        Nuclei_Texture_SumVariance_DNA_10_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                         1.210472
#                    AKT1-2                                         0.405894
#                    ARID1B-1                                      -0.779524
#                    ARID1B-2                                      -0.306734
#                    ATF4-1                                         0.092861
#
#                                        Nuclei_Texture_SumVariance_DNA_20_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                         0.595231
#                    AKT1-2                                        -0.098476
#                    ARID1B-1                                      -0.689953
#                    ARID1B-2                                      -0.340945
#                    ATF4-1                                         0.204620
#
#                                        Nuclei_Texture_SumVariance_DNA_5_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                        1.444966
#                    AKT1-2                                        0.651047
#                    ARID1B-1                                     -0.724053
#                    ARID1B-2                                     -0.228247
#                    ATF4-1                                        0.045101
#
#                                        Nuclei_Texture_Variance_AGP_5_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                     1.415588
#                    AKT1-2                                     0.598719
#                    ARID1B-1                                  -0.712559
#                    ARID1B-2                                  -0.759630
#                    ATF4-1                                     0.019923
#
#                                        Nuclei_Texture_Variance_DNA_10_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                      1.565379
#                    AKT1-2                                      0.912346
#                    ARID1B-1                                   -0.533418
#                    ARID1B-2                                   -0.263143
#                    ATF4-1                                     -0.063601
#
#                                        Nuclei_Texture_Variance_DNA_20_0  \
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                      1.401021
#                    AKT1-2                                      0.730771
#                    ARID1B-1                                   -0.577375
#                    ARID1B-2                                   -0.294382
#                    ATF4-1                                     -0.008132
#
#                                        Nuclei_Texture_Variance_DNA_5_0
# Metadata_cell_line Metadata_pert_name
# A549               AKT1-1                                     1.537235
#                    AKT1-2                                     0.847872
#                    ARID1B-1                                  -0.584598
#                    ARID1B-2                                  -0.193774
#                    ATF4-1                                    -0.011010
#
# [5 rows x 943 columns]

# %%
x_consensus_df = (
    x_consensus_df
    .reset_index()
    .query("Metadata_pert_name in @all_measurements_df.Metadata_pert_name.unique()")
    .query("Metadata_cell_line in @all_measurements_df.Metadata_cell_line.unique()")
    .reset_index(drop=True)
    .reset_index()
    .rename(
        {
            "index": "Metadata_profile_id"
        },
        axis='columns'
    )
)
x_consensus_df.Metadata_profile_id = ["profile_{}".format(x) for x in x_consensus_df.Metadata_profile_id]

print(x_consensus_df.shape)
x_consensus_df.head(5)
# Out:
# (357, 946)
#   Metadata_profile_id Metadata_cell_line Metadata_pert_name  \
# 0           profile_0               A549             AKT1-1
# 1           profile_1               A549             AKT1-2
# 2           profile_2               A549           ARID1B-1
# 3           profile_3               A549           ARID1B-2
# 4           profile_4               A549             ATF4-1
#
#    Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                  0.503175                     0.110106
# 1                  0.100797                    -0.101499
# 2                 -0.130649                     0.448408
# 3                  0.084150                     0.552944
# 4                  0.010101                    -0.079724
#
#    Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# 0                     -0.045764               -0.263006
# 1                     -0.052097               -0.010985
# 2                      0.292884               -0.412305
# 3                      0.326113               -0.610228
# 4                     -0.053684                0.125938
#
#    Cells_AreaShape_Orientation  Cells_AreaShape_Zernike_0_0  \
# 0                    -0.070482                    -0.062049
# 1                    -0.012921                     0.125160
# 2                     0.035924                    -0.428059
# 3                     0.033123                    -0.561141
# 4                     0.022919                     0.019611
#
#    Cells_AreaShape_Zernike_1_1  ...  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                     0.183216  ...                           0.774055
# 1                     0.162637  ...                           0.406455
# 2                     0.025479  ...                          -0.281958
# 3                     0.100766  ...                           0.093125
# 4                     0.002694  ...                          -0.044726
#
#    Nuclei_Texture_SumVariance_AGP_20_0  Nuclei_Texture_SumVariance_AGP_5_0  \
# 0                             1.033896                            1.433717
# 1                             0.367872                            0.598358
# 2                            -0.785849                           -0.795507
# 3                            -0.469950                           -0.650276
# 4                             0.151566                            0.048038
#
#    Nuclei_Texture_SumVariance_DNA_10_0  Nuclei_Texture_SumVariance_DNA_20_0  \
# 0                             1.210472                             0.595231
# 1                             0.405894                            -0.098476
# 2                            -0.779524                            -0.689953
# 3                            -0.306734                            -0.340945
# 4                             0.092861                             0.204620
#
#    Nuclei_Texture_SumVariance_DNA_5_0  Nuclei_Texture_Variance_AGP_5_0  \
# 0                            1.444966                         1.415588
# 1                            0.651047                         0.598719
# 2                           -0.724053                        -0.712559
# 3                           -0.228247                        -0.759630
# 4                            0.045101                         0.019923
#
#    Nuclei_Texture_Variance_DNA_10_0  Nuclei_Texture_Variance_DNA_20_0  \
# 0                          1.565379                          1.401021
# 1                          0.912346                          0.730771
# 2                         -0.533418                         -0.577375
# 3                         -0.263143                         -0.294382
# 4                         -0.063601                         -0.008132
#
#    Nuclei_Texture_Variance_DNA_5_0
# 0                         1.537235
# 1                         0.847872
# 2                        -0.584598
# 3                        -0.193774
# 4                        -0.011010
#
# [5 rows x 946 columns]

# %% [markdown]
# ### Cell health assays data

# %%
# %%time 

y_consensus_df = modz(
    y_df,
    features=cell_health_features,
    replicate_columns=cell_health_meta_features,
    precision=5
)

print(y_consensus_df.shape)
y_consensus_df.head()
# Out:
# (364, 70)
# CPU times: user 5.52 s, sys: 0 ns, total: 5.52 s
# Wall time: 5.52 s
#                   cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# cell_id guide
# A549    AKT1-1           -0.005795                                0.580351
#         AKT1-2            0.050169                                1.277730
#         ARID1B-1          0.118598                                1.198685
#         ARID1B-2         -0.072919                                0.317079
#         ATF4-1            4.286179                                0.007467
#
#                   cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# cell_id guide
# A549    AKT1-1                             0.013975          0.381958
#         AKT1-2                             0.241808          0.577422
#         ARID1B-1                           0.165140          0.330071
#         ARID1B-2                          -0.089281          0.155305
#         ATF4-1                             3.284383         -2.246762
#
#                   cc_all_n_spots_h2ax_mean  \
# cell_id guide
# A549    AKT1-1                    0.150696
#         AKT1-2                    0.220829
#         ARID1B-1                  0.417723
#         ARID1B-2                 -0.385316
#         ATF4-1                    3.015881
#
#                   cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# cell_id guide
# A549    AKT1-1                                     0.162511
#         AKT1-2                                     0.366989
#         ARID1B-1                                   0.514065
#         ARID1B-2                                  -0.300279
#         ATF4-1                                     3.065773
#
#                   cc_all_nucleus_area_mean  cc_all_nucleus_roundness_mean  \
# cell_id guide
# A549    AKT1-1                   -0.167603                       0.040322
#         AKT1-2                   -0.278044                      -0.182571
#         ARID1B-1                 -0.308749                      -0.172735
#         ARID1B-2                 -0.120261                      -0.299718
#         ATF4-1                    2.854124                       1.246508
#
#                   cc_cc_early_mitosis  cc_cc_g1  ...  vb_num_live_cells  \
# cell_id guide                                    ...
# A549    AKT1-1               0.375966  0.043915  ...           0.438339
#         AKT1-2               0.736046 -1.023968  ...           0.067568
#         ARID1B-1             0.148168 -0.606599  ...           0.100365
#         ARID1B-2             0.012239 -0.221492  ...           0.283802
#         ATF4-1               0.049095  0.923187  ...          -2.434136
#
#                   vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# cell_id guide
# A549    AKT1-1                    0.059414                     -0.065050
#         AKT1-2                    0.256141                      0.575026
#         ARID1B-1                  0.299229                      0.501941
#         ARID1B-2                  0.143096                      0.493883
#         ATF4-1                    0.315381                      0.509217
#
#                   vb_percent_dead  vb_percent_dead_only  \
# cell_id guide
# A549    AKT1-1          -0.020236             -0.007970
#         AKT1-2           0.225091              0.220461
#         ARID1B-1         0.055517              0.047697
#         ARID1B-2        -0.084415             -0.085658
#         ATF4-1           0.100668              0.104857
#
#                   vb_percent_early_apoptosis  vb_percent_late_apoptosis  \
# cell_id guide
# A549    AKT1-1                      0.082424                   0.000000
#         AKT1-2                      0.132834                   0.386327
#         ARID1B-1                    0.249557                   0.283246
#         ARID1B-2                    0.136790                   0.111855
#         ATF4-1                      0.332291                   0.192878
#
#                   vb_percent_live  vb_ros_back_mean  vb_ros_mean
# cell_id guide
# A549    AKT1-1           0.020263          0.408214     0.654575
#         AKT1-2          -0.224965          0.284962     0.567898
#         ARID1B-1        -0.055445         -0.363766    -0.205937
#         ARID1B-2         0.084439          0.198285    -0.162976
#         ATF4-1          -0.100596         -0.811271    -0.092505
#
# [5 rows x 70 columns]

# %%
y_consensus_df = (
    y_consensus_df
    .reset_index()
    .reset_index(drop=True)
    .merge(
        x_consensus_df.loc[:, y_meta_merge_cols],
        left_on=["guide", "cell_id"],
        right_on=["Metadata_pert_name", "Metadata_cell_line"],
        how="right"
    )
    .loc[:, y_columns]
    .drop(["guide", "cell_id"], axis="columns")
)

print(y_consensus_df.shape)
y_consensus_df.head(5)
# Out:
# (357, 73)
#   Metadata_profile_id Metadata_pert_name Metadata_cell_line  cc_all_high_h2ax  \
# 0           profile_0             AKT1-1               A549         -0.005795
# 1           profile_1             AKT1-2               A549          0.050169
# 2           profile_2           ARID1B-1               A549          0.118598
# 3           profile_3           ARID1B-2               A549         -0.072919
# 4           profile_4             ATF4-1               A549          4.286179
#
#    cc_all_large_notround_polynuclear_mean  cc_all_large_round_polyploid_mean  \
# 0                                0.580351                           0.013975
# 1                                1.277730                           0.241808
# 2                                1.198685                           0.165140
# 3                                0.317079                          -0.089281
# 4                                0.007467                           3.284383
#
#    cc_all_n_objects  cc_all_n_spots_h2ax_mean  \
# 0          0.381958                  0.150696
# 1          0.577422                  0.220829
# 2          0.330071                  0.417723
# 3          0.155305                 -0.385316
# 4         -2.246762                  3.015881
#
#    cc_all_n_spots_h2ax_per_nucleus_area_mean  cc_all_nucleus_area_mean  ...  \
# 0                                   0.162511                 -0.167603  ...
# 1                                   0.366989                 -0.278044  ...
# 2                                   0.514065                 -0.308749  ...
# 3                                  -0.300279                 -0.120261  ...
# 4                                   3.065773                  2.854124  ...
#
#    vb_num_live_cells  vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# 0           0.438339                  0.059414                     -0.065050
# 1           0.067568                  0.256141                      0.575026
# 2           0.100365                  0.299229                      0.501941
# 3           0.283802                  0.143096                      0.493883
# 4          -2.434136                  0.315381                      0.509217
#
#    vb_percent_dead  vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0        -0.020236             -0.007970                    0.082424
# 1         0.225091              0.220461                    0.132834
# 2         0.055517              0.047697                    0.249557
# 3        -0.084415             -0.085658                    0.136790
# 4         0.100668              0.104857                    0.332291
#
#    vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                   0.000000         0.020263          0.408214     0.654575
# 1                   0.386327        -0.224965          0.284962     0.567898
# 2                   0.283246        -0.055445         -0.363766    -0.205937
# 3                   0.111855         0.084439          0.198285    -0.162976
# 4                   0.192878        -0.100596         -0.811271    -0.092505
#
# [5 rows x 73 columns]

# %%
# Confirm that matrices are aligned
pd.testing.assert_series_equal(
    x_consensus_df.Metadata_profile_id,
    y_consensus_df.Metadata_profile_id,
    check_names=True
)

# Are the guides aligned?
pd.testing.assert_series_equal(
    x_consensus_df.Metadata_pert_name,
    y_consensus_df.Metadata_pert_name,
    check_names=True
)

# Are the cells aligned?
pd.testing.assert_series_equal(
    x_consensus_df.Metadata_cell_line,
    y_consensus_df.Metadata_cell_line,
    check_names=True
)

# %%
# %%time
consensus_folder = 'data/consensus/'

file = Path(consensus_folder, "{}_agg_cell_painting_median.tsv.gz".format(method))
x_median_df.to_csv(file, sep="\t", index=False)

file = Path(consensus_folder, "{}_agg_cell_health_median.tsv.gz".format(method))
y_median_df.to_csv(file, sep="\t", index=False)

file = Path(consensus_folder, "{}_agg_cell_painting_modz.tsv.gz".format(method))
x_consensus_df.to_csv(file, sep="\t", index=False)

file = Path(consensus_folder, "{}_agg_cell_health_modz.tsv.gz".format(method))
y_consensus_df.to_csv(file, sep="\t", index=False)
# Out:
# CPU times: user 3.92 s, sys: 36 ms, total: 3.95 s
# Wall time: 4.21 s
