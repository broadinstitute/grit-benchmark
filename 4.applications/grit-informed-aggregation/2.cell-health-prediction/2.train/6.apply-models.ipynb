# %% [markdown]
# ## Apply all Cell-Health Models to Training and Testing Sets
#
# **Gregory Way, 2019**

# %%
import os
import pandas as pd
from joblib import load

from scripts.ml_utils import load_train_test, load_models
# Out:
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1097: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1480: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# /home/ubuntu/miniconda3/envs/cell-health-HYT/lib/python3.7/site-packages/dask/array/random.py:27: FutureWarning: dask.array.random.doc_wraps is deprecated and will be removed in a future version
#   FutureWarning,

# %%
# %matplotlib inline

# %%
def apply_model(model, feature, train_x, test_x):
    """
    Apply model to training and testing matrix
    """
    pred_train_df = (
        pd.DataFrame(model.predict(train_x), columns=["score"])
        .assign(profiles=train_x.index,
                Metadata_data_type="train",
                model=feature)
    )
    pred_test_df = (
        pd.DataFrame(model.predict(test_x), columns=["score"])
        .assign(profiles=test_x.index,
                Metadata_data_type="test",
                model=feature)
    )

    pred_df = pd.concat([pred_train_df, pred_test_df]).reset_index(drop=True)
    return pred_df

def sample_squared_error(scores, y):
    """
    Calculate the squared error per sample depending on model scores
    """
    metadata_cols = [x for x in scores.columns if x.startswith("Metadata_")]
    scores_values = scores.drop(metadata_cols, axis="columns")
    
    all_squared_error = {}
    for cell_health_feature in scores_values.columns:
        y_subset_df = y.loc[:, cell_health_feature].dropna().T
        scores_subset = scores_values.loc[:, cell_health_feature].reindex(y_subset_df.index).T

        squared_error = (y_subset_df - scores_subset) ** 2
        all_squared_error[cell_health_feature] = squared_error
    
    return pd.DataFrame(all_squared_error).reindex(scores.index)

# %% [markdown]
# ## 1) Load Models and Model Coefficients
#
# For real data and shuffled model data.

# %%
consensus = "modz"
method = "median"
# method = "weighted"

# %%
model_dict, model_coef = load_models(model_dir=f"models/{method}_agg", consensus=consensus)
shuffle_model_dict, shuffle_model_coef = load_models(model_dir=f"models/{method}_agg", shuffle=True, consensus=consensus)

# %%
# Load Metadata Mapping File
data_dir = os.path.join("..", "1.generate-profiles", "data") #"1.generate-profiles", 
file = os.path.join(data_dir, f"{method}_profile_id_metadata_mapping.tsv")
metadata_df = pd.read_csv(file, sep='\t')

metadata_df.head()
# Out:
#   Metadata_profile_id Metadata_cell_line Metadata_pert_name
# 0           profile_0               A549             AKT1-1
# 1           profile_1               A549             AKT1-2
# 2           profile_2               A549           ARID1B-1
# 3           profile_3               A549           ARID1B-2
# 4           profile_4               A549             ATF4-1

# %% [markdown]
# ## 2) Load Training and Testing Data

# %%
train_folder = f"data/train_test/{method}_agg/"

# %%
x_train_df, x_test_df, y_train_df, y_test_df = load_train_test(data_dir=train_folder,
                                                               drop_metadata=True, consensus=consensus)

# %% [markdown]
# ## 3) Output Model Coefficients

# %%
# Extract all model coefficients and output to file
coef_df = pd.DataFrame(model_coef)
coef_df.index = x_test_df.columns
coef_df.index.name = "features"

file = os.path.join("results", "{}_agg".format(method),
                    "all_model_coefficients_{}.tsv".format(consensus))
coef_df.to_csv(file, sep='\t', index=True)

print(coef_df.shape)
coef_df.head(2)
# Out:
# (943, 70)
#                              cell_health_modz_target_cc_cc_g2  \
# features
# Cells_AreaShape_Center_Y                             0.025784
# Cells_AreaShape_Compactness                          0.000000
#
#                              cell_health_modz_target_cc_mitosis_n_objects  \
# features
# Cells_AreaShape_Center_Y                                         0.015058
# Cells_AreaShape_Compactness                                      0.000000
#
#                              cell_health_modz_target_cc_g1_n_objects  \
# features
# Cells_AreaShape_Center_Y                               -0.000000e+00
# Cells_AreaShape_Compactness                            -5.625015e-07
#
#                              cell_health_modz_target_vb_infection_percentage  \
# features
# Cells_AreaShape_Center_Y                                                -0.0
# Cells_AreaShape_Compactness                                              0.0
#
#                              cell_health_modz_target_cc_late_mitosis_high_h2ax  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                               -0.0
#
#                              cell_health_modz_target_cc_s_n_spots_h2ax_per_nucleus_area_mean  \
# features
# Cells_AreaShape_Center_Y                                                  -0.0
# Cells_AreaShape_Compactness                                                0.0
#
#                              cell_health_modz_target_vb_ros_mean  \
# features
# Cells_AreaShape_Center_Y                                -0.03125
# Cells_AreaShape_Compactness                              0.00000
#
#                              cell_health_modz_target_vb_ros_back_mean  \
# features
# Cells_AreaShape_Center_Y                                    -0.014778
# Cells_AreaShape_Compactness                                  0.000000
#
#                              cell_health_modz_target_cc_cc_late_mitosis  \
# features
# Cells_AreaShape_Center_Y                                       0.018794
# Cells_AreaShape_Compactness                                    0.068026
#
#                              cell_health_modz_target_vb_percent_live  ...  \
# features                                                              ...
# Cells_AreaShape_Center_Y                                    0.002111  ...
# Cells_AreaShape_Compactness                                 0.000000  ...
#
#                              cell_health_modz_target_cc_cc_n_spots_h2ax_per_nucleus_area_mean  \
# features
# Cells_AreaShape_Center_Y                                                  -0.0
# Cells_AreaShape_Compactness                                                0.0
#
#                              cell_health_modz_target_cc_g1_high_h2ax  \
# features
# Cells_AreaShape_Center_Y                                         0.0
# Cells_AreaShape_Compactness                                     -0.0
#
#                              cell_health_modz_target_vb_live_cell_area  \
# features
# Cells_AreaShape_Center_Y                                      0.014578
# Cells_AreaShape_Compactness                                   0.076844
#
#                              cell_health_modz_target_cc_polynuclear_n_spots_h2ax_mean  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                                0.0
#
#                              cell_health_modz_target_cc_early_mitosis_high_h2ax  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                                0.0
#
#                              cell_health_modz_target_cc_all_large_round_polyploid_mean  \
# features
# Cells_AreaShape_Center_Y                                              0.011547
# Cells_AreaShape_Compactness                                           0.000000
#
#                              cell_health_modz_target_cc_cc_mitosis  \
# features
# Cells_AreaShape_Center_Y                                  0.007674
# Cells_AreaShape_Compactness                              -0.000000
#
#                              cell_health_modz_target_cc_cc_g1  \
# features
# Cells_AreaShape_Center_Y                            -0.009514
# Cells_AreaShape_Compactness                          0.000000
#
#                              cell_health_modz_target_cc_cc_n_spots_h2ax_mean  \
# features
# Cells_AreaShape_Center_Y                                                 0.0
# Cells_AreaShape_Compactness                                              0.0
#
#                              cell_health_modz_target_cc_polyploid_high_h2ax
# features
# Cells_AreaShape_Center_Y                                               -0.0
# Cells_AreaShape_Compactness                                             0.0
#
# [2 rows x 70 columns]

# %%
# Extract all model coefficients and output to file
shuffle_coef_df = pd.DataFrame(shuffle_model_coef)
shuffle_coef_df.index = x_test_df.columns
shuffle_coef_df.index.name = "features"

file = os.path.join("results", "{}_agg".format(method),
                    "all_model_coefficients_shuffled_{}.tsv".format(consensus))
shuffle_coef_df.to_csv(file, sep='\t', index=True)

print(shuffle_coef_df.shape)
shuffle_coef_df.head(2)
# Out:
# (943, 70)
#                              cell_health_modz_target_cc_mitosis_high_h2ax  \
# features
# Cells_AreaShape_Center_Y                                             -0.0
# Cells_AreaShape_Compactness                                          -0.0
#
#                              cell_health_modz_target_cc_cc_n_spots_h2ax_per_nucleus_area_mean  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                                0.0
#
#                              cell_health_modz_target_cc_cc_early_mitosis  \
# features
# Cells_AreaShape_Center_Y                                            -0.0
# Cells_AreaShape_Compactness                                         -0.0
#
#                              cell_health_modz_target_vb_percent_late_apoptosis  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                               -0.0
#
#                              cell_health_modz_target_cc_s_n_objects  \
# features
# Cells_AreaShape_Center_Y                                        0.0
# Cells_AreaShape_Compactness                                     0.0
#
#                              cell_health_modz_target_vb_live_cell_area  \
# features
# Cells_AreaShape_Center_Y                                          -0.0
# Cells_AreaShape_Compactness                                       -0.0
#
#                              cell_health_modz_target_cc_g1_high_h2ax  \
# features
# Cells_AreaShape_Center_Y                                   -0.054148
# Cells_AreaShape_Compactness                                 0.000000
#
#                              cell_health_modz_target_vb_live_cell_width_length  \
# features
# Cells_AreaShape_Center_Y                                                  -0.0
# Cells_AreaShape_Compactness                                                0.0
#
#                              cell_health_modz_target_vb_live_cell_roundness  \
# features
# Cells_AreaShape_Center_Y                                                0.0
# Cells_AreaShape_Compactness                                            -0.0
#
#                              cell_health_modz_target_vb_percent_dead_only  \
# features
# Cells_AreaShape_Center_Y                                              0.0
# Cells_AreaShape_Compactness                                           0.0
#
#                              ...  \
# features                     ...
# Cells_AreaShape_Center_Y     ...
# Cells_AreaShape_Compactness  ...
#
#                              cell_health_modz_target_vb_percent_early_apoptosis  \
# features
# Cells_AreaShape_Center_Y                                                  -0.0
# Cells_AreaShape_Compactness                                               -0.0
#
#                              cell_health_modz_target_cc_all_n_spots_h2ax_mean  \
# features
# Cells_AreaShape_Center_Y                                                  0.0
# Cells_AreaShape_Compactness                                              -0.0
#
#                              cell_health_modz_target_cc_late_mitosis_n_spots_h2ax_per_nucleus_area_mean  \
# features
# Cells_AreaShape_Center_Y                                                  -0.0
# Cells_AreaShape_Compactness                                               -0.0
#
#                              cell_health_modz_target_vb_percent_caspase_dead_only  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                               -0.0
#
#                              cell_health_modz_target_vb_percent_dead  \
# features
# Cells_AreaShape_Center_Y                                        -0.0
# Cells_AreaShape_Compactness                                      0.0
#
#                              cell_health_modz_target_cc_g2_n_spots_h2ax_mean  \
# features
# Cells_AreaShape_Center_Y                                           -0.000000
# Cells_AreaShape_Compactness                                        -0.053503
#
#                              cell_health_modz_target_cc_g2_g1_count  \
# features
# Cells_AreaShape_Center_Y                                        0.0
# Cells_AreaShape_Compactness                                    -0.0
#
#                              cell_health_modz_target_cc_all_large_notround_polynuclear_mean  \
# features
# Cells_AreaShape_Center_Y                                                   0.0
# Cells_AreaShape_Compactness                                               -0.0
#
#                              cell_health_modz_target_cc_g2_plus_all_m_count  \
# features
# Cells_AreaShape_Center_Y                                                0.0
# Cells_AreaShape_Compactness                                            -0.0
#
#                              cell_health_modz_target_cc_cc_s
# features
# Cells_AreaShape_Center_Y                                 0.0
# Cells_AreaShape_Compactness                              0.0
#
# [2 rows x 70 columns]

# %% [markdown]
# ## 4) Apply all models
#
# For real and shuffled data.

# %%
all_scores = []
all_shuffle_scores = []
for cell_health_feature in model_dict.keys():
    # Apply Real Model Classifiers
    model_clf = model_dict[cell_health_feature]
    pred_df = apply_model(model=model_clf,
                          feature=cell_health_feature,
                          train_x=x_train_df,
                          test_x=x_test_df)
    all_scores.append(pred_df)
    
    # Apply Shuffled Model Classifiers
    shuffle_model_clf = shuffle_model_dict[cell_health_feature]
    shuffle_pred_df = apply_model(model=shuffle_model_clf,
                                  feature=cell_health_feature,
                                  train_x=x_train_df,
                                  test_x=x_test_df)
    all_shuffle_scores.append(shuffle_pred_df)

# %% [markdown]
# ## 5) Concatenate scores with Metadata

# %%
# Concatenate real data scores
all_scores = (
    pd.concat(all_scores)
    .reset_index(drop=True)
    .pivot_table(index=["profiles", "Metadata_data_type"],
                 columns="model",
                 values="score")
    .reset_index()
)

all_scores = (
    metadata_df.merge(
        all_scores,
        left_on="Metadata_profile_id",
        right_on="profiles"
    )
    .drop("profiles", axis="columns")
)

all_scores.index = all_scores.Metadata_profile_id
all_scores = all_scores.drop("Metadata_profile_id", axis="columns")

# Remove prefix of variable columns
strip_text = "cell_health_{}_target_".format(consensus)
all_scores.columns = [x.replace(strip_text, "") for x in all_scores.columns]

# Output file
file = os.path.join(
    "results", f"{method}_agg", "all_model_predictions_{}.tsv".format(consensus)
)
all_scores.to_csv(file, sep='\t', index=True)

print(all_scores.shape)
all_scores.head(2)
# Out:
# (357, 73)
#                     Metadata_cell_line Metadata_pert_name Metadata_data_type  \
# Metadata_profile_id
# profile_0                         A549             AKT1-1              train
# profile_1                         A549             AKT1-2              train
#
#                      cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# Metadata_profile_id
# profile_0                    0.228417                                0.816116
# profile_1                    0.012612                                0.598985
#
#                      cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# Metadata_profile_id
# profile_0                                     0.148530          0.331433
# profile_1                                     0.055341          0.455854
#
#                      cc_all_n_spots_h2ax_mean  \
# Metadata_profile_id
# profile_0                            0.204878
# profile_1                           -0.003243
#
#                      cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# Metadata_profile_id
# profile_0                                             0.142605
# profile_1                                            -0.058270
#
#                      cc_all_nucleus_area_mean  ...  vb_num_live_cells  \
# Metadata_profile_id                            ...
# profile_0                           -0.114986  ...           0.082109
# profile_1                           -0.251804  ...           0.251683
#
#                      vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# Metadata_profile_id
# profile_0                            0.332015                      0.428979
# profile_1                            0.367668                      0.448494
#
#                      vb_percent_dead  vb_percent_dead_only  \
# Metadata_profile_id
# profile_0                   0.292545              0.309882
# profile_1                   0.445084              0.387040
#
#                      vb_percent_early_apoptosis  vb_percent_late_apoptosis  \
# Metadata_profile_id
# profile_0                              0.152234                   0.354071
# profile_1                              0.185080                   0.399842
#
#                      vb_percent_live  vb_ros_back_mean  vb_ros_mean
# Metadata_profile_id
# profile_0                  -0.293712          0.294949     0.526890
# profile_1                  -0.446246          0.367320     0.627541
#
# [2 rows x 73 columns]

# %%
# Concatenate shuffled data scores
all_shuffle_scores = (
    pd.concat(all_shuffle_scores)
    .reset_index(drop=True)
    .pivot_table(index=["profiles", "Metadata_data_type"],
                 columns="model",
                 values="score")
    .reset_index()
)

all_shuffle_scores = (
    metadata_df.merge(all_shuffle_scores,
                      left_on="Metadata_profile_id",
                      right_on="profiles")
    .drop("profiles", axis="columns")
)

all_shuffle_scores.index = all_shuffle_scores.Metadata_profile_id
all_shuffle_scores = all_shuffle_scores.drop("Metadata_profile_id", axis="columns")

# Remove prefix of variable columns
strip_text = "cell_health_{}_target_".format(consensus)
all_shuffle_scores.columns = [x.replace(strip_text, "") for x in all_shuffle_scores.columns]

# Output file
file = os.path.join(
    "results", f"{method}_agg", "all_model_predictions_shuffled_{}.tsv".format(consensus)
)
all_shuffle_scores.to_csv(file, sep='\t', index=True)

print(all_shuffle_scores.shape)
all_shuffle_scores.head(2)
# Out:
# (357, 73)
#                     Metadata_cell_line Metadata_pert_name Metadata_data_type  \
# Metadata_profile_id
# profile_0                         A549             AKT1-1              train
# profile_1                         A549             AKT1-2              train
#
#                      cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# Metadata_profile_id
# profile_0                    0.228903                                0.235144
# profile_1                    0.158393                                0.235144
#
#                      cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# Metadata_profile_id
# profile_0                                     0.233312         -0.059212
# profile_1                                     0.233312         -0.044404
#
#                      cc_all_n_spots_h2ax_mean  \
# Metadata_profile_id
# profile_0                            0.164803
# profile_1                            0.089701
#
#                      cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# Metadata_profile_id
# profile_0                                             0.076621
# profile_1                                             0.039341
#
#                      cc_all_nucleus_area_mean  ...  vb_num_live_cells  \
# Metadata_profile_id                            ...
# profile_0                            0.067090  ...          -0.258438
# profile_1                            0.052826  ...          -0.257040
#
#                      vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# Metadata_profile_id
# profile_0                            0.235648                      0.164073
# profile_1                            0.197561                      0.168769
#
#                      vb_percent_dead  vb_percent_dead_only  \
# Metadata_profile_id
# profile_0                  -0.129406              0.271165
# profile_1                  -0.063346              0.269579
#
#                      vb_percent_early_apoptosis  vb_percent_late_apoptosis  \
# Metadata_profile_id
# profile_0                              0.139402                   0.228445
# profile_1                              0.139402                   0.228445
#
#                      vb_percent_live  vb_ros_back_mean  vb_ros_mean
# Metadata_profile_id
# profile_0                  -0.261712          0.016651     0.063434
# profile_1                  -0.264186          0.020347     0.050140
#
# [2 rows x 73 columns]

# %% [markdown]
# ## 6) Calculate the Squared Error of Individual Samples
#
# For real and shuffled data

# %%
y_df = pd.concat([y_train_df, y_test_df]).reindex(all_scores.index)

print(y_df.shape)
y_df.head(2)
# Out:
# (357, 70)
#                      cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# Metadata_profile_id
# profile_0                   -0.005795                                0.580351
# profile_1                    0.050169                                1.277730
#
#                      cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# Metadata_profile_id
# profile_0                                     0.013975          0.381958
# profile_1                                     0.241808          0.577422
#
#                      cc_all_n_spots_h2ax_mean  \
# Metadata_profile_id
# profile_0                            0.150696
# profile_1                            0.220829
#
#                      cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# Metadata_profile_id
# profile_0                                             0.162511
# profile_1                                             0.366989
#
#                      cc_all_nucleus_area_mean  cc_all_nucleus_roundness_mean  \
# Metadata_profile_id
# profile_0                           -0.167603                       0.040322
# profile_1                           -0.278044                      -0.182571
#
#                      cc_cc_early_mitosis  cc_cc_g1  ...  vb_num_live_cells  \
# Metadata_profile_id                                 ...
# profile_0                       0.375966  0.043915  ...           0.438339
# profile_1                       0.736046 -1.023968  ...           0.067568
#
#                      vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# Metadata_profile_id
# profile_0                            0.059414                     -0.065050
# profile_1                            0.256141                      0.575026
#
#                      vb_percent_dead  vb_percent_dead_only  \
# Metadata_profile_id
# profile_0                  -0.020236             -0.007970
# profile_1                   0.225091              0.220461
#
#                      vb_percent_early_apoptosis  vb_percent_late_apoptosis  \
# Metadata_profile_id
# profile_0                              0.082424                   0.000000
# profile_1                              0.132834                   0.386327
#
#                      vb_percent_live  vb_ros_back_mean  vb_ros_mean
# Metadata_profile_id
# profile_0                   0.020263          0.408214     0.654575
# profile_1                  -0.224965          0.284962     0.567898
#
# [2 rows x 70 columns]

# %%
all_score_error = sample_squared_error(scores=all_scores, y=y_df)

all_score_error = (
    metadata_df.merge(
        all_score_error,
        left_on="Metadata_profile_id",
        right_index=True
    )
)

# Output file
file = os.path.join(
    "results", f"{method}_agg", "all_model_sample_squared_error_{}.tsv".format(consensus)
)
all_score_error.to_csv(file, sep='\t', index=False)

print(all_score_error.shape)
all_score_error.head(2)
# Out:
# (357, 73)
#   Metadata_profile_id Metadata_cell_line Metadata_pert_name  cc_all_high_h2ax  \
# 0           profile_0               A549             AKT1-1          0.054855
# 1           profile_1               A549             AKT1-2          0.001411
#
#    cc_all_large_notround_polynuclear_mean  cc_all_large_round_polyploid_mean  \
# 0                                0.055585                           0.018105
# 1                                0.460695                           0.034770
#
#    cc_all_n_objects  cc_all_n_spots_h2ax_mean  \
# 0          0.002553                  0.002936
# 1          0.014779                  0.050208
#
#    cc_all_n_spots_h2ax_per_nucleus_area_mean  cc_all_nucleus_area_mean  ...  \
# 0                                   0.000396                  0.002769  ...
# 1                                   0.180845                  0.000689  ...
#
#    vb_num_live_cells  vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# 0           0.126900                  0.074311                      0.244065
# 1           0.033898                  0.012438                      0.016010
#
#    vb_percent_dead  vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0         0.097832              0.101030                    0.004873
# 1         0.048397              0.027749                    0.002730
#
#    vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                   0.125366         0.098580          0.012829     0.016303
# 1                   0.000183         0.048965          0.006783     0.003557
#
# [2 rows x 73 columns]

# %%
all_shuffle_score_error = sample_squared_error(scores=all_shuffle_scores, y=y_df)

all_shuffle_score_error = (
    metadata_df.merge(
        all_shuffle_score_error,
        left_on="Metadata_profile_id",
        right_index=True
    )
)

# Output file
file = os.path.join(
    "results", f"{method}_agg", "all_model_sample_squared_error_shuffled_{}.tsv".format(consensus)
)
all_shuffle_score_error.to_csv(file, sep='\t', index=False)

print(all_shuffle_score_error.shape)
all_shuffle_score_error.head()
# Out:
# (357, 73)
#   Metadata_profile_id Metadata_cell_line Metadata_pert_name  cc_all_high_h2ax  \
# 0           profile_0               A549             AKT1-1          0.055083
# 1           profile_1               A549             AKT1-2          0.011712
# 2           profile_2               A549           ARID1B-1          0.002528
# 3           profile_3               A549           ARID1B-2          0.106506
# 4           profile_4               A549             ATF4-1         11.715532
#
#    cc_all_large_notround_polynuclear_mean  cc_all_large_round_polyploid_mean  \
# 0                                0.119168                           0.048109
# 1                                1.086985                           0.000072
# 2                                0.928410                           0.004647
# 3                                0.006713                           0.104066
# 4                                0.051837                           9.309035
#
#    cc_all_n_objects  cc_all_n_spots_h2ax_mean  \
# 0          0.194631                  0.000199
# 1          0.386668                  0.017194
# 2          0.118477                  0.078418
# 3          0.035216                  0.397377
# 4          4.037200                  4.565127
#
#    cc_all_n_spots_h2ax_per_nucleus_area_mean  cc_all_nucleus_area_mean  ...  \
# 0                                   0.007377                  0.055081  ...
# 1                                   0.107353                  0.109475  ...
# 2                                   0.190376                  0.085412  ...
# 3                                   0.140361                  0.014569  ...
# 4                                   7.322290                  6.369306  ...
#
#    vb_num_live_cells  vb_percent_all_apoptosis  vb_percent_caspase_dead_only  \
# 0           0.485499                  0.031058                      0.052497
# 1           0.105370                  0.003432                      0.165045
# 2           0.102260                  0.004801                      0.037218
# 3           0.253177                  0.006221                      0.045716
# 4           4.735934                  0.010589                      0.091343
#
#    vb_percent_dead  vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0         0.011918              0.077916                    0.003246
# 1         0.083196              0.002413                    0.000043
# 2         0.018486              0.052900                    0.012134
# 3         0.075955              0.133169                    0.000007
# 4         0.029103              0.035005                    0.037206
#
#    vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                   0.052187         0.079510          0.153322     0.349447
# 1                   0.024927         0.001538          0.070021     0.268073
# 2                   0.003003         0.043814          0.142750     0.056966
# 3                   0.013593         0.122005          0.032024     0.046444
# 4                   0.001265         0.015247          0.685666     0.037060
#
# [5 rows x 73 columns]
